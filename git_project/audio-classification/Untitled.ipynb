# %%
# coding= UTF-8

import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import soundfile as sf

def extract_feature(file_name):
    X, sample_rate = sf.read(file_name, dtype='float32')
    if X.ndim > 1:
        X = X[:,0]
    X = X.T

    # short term fourier transform
    stft = np.abs(librosa.stft(X))

    # mfcc
#     mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
#     print('mfcc shape : {}'.format(mfccs.shape))

    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) # 13
    print('mfcc shape : {}'.format(mfccs.shape))
    
    # chroma
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    print('chroma shape : {}'.format(chroma.shape))
#     # melspectrogram
#     mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
#     print('melspectrogram shape : {}'.format(mel.shape))
#     # spectral contrast
#     contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
#     print('contrast shape : {}'.format(contrast.shape))

    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
    print('tonnetz shape : {}'.format(tonnetz.shape))
#     return mfccs,chroma,mel,contrast,tonnetz
    return mfccs,chroma,tonnetz

def parse_audio_files(parent_dir,sub_dirs,file_ext='*.wav'):
    features, labels = np.empty((0,58)), np.empty(0) # 31
    files_order = []
    for label, sub_dir in enumerate(sub_dirs):
        print(sub_dir)
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)):
            print(fn)
            files_order.append(fn)
            try:
#                 mfccs, chroma, mel, contrast,tonnetz = extract_feature(fn)
                 mfccs, chroma,tonnetz = extract_feature(fn)
            except Exception as e:
                print("[Error] extract feature error. %s" % (e))
                continue
#             ext_features = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
            ext_features = np.hstack([mfccs,chroma,tonnetz])
            features = np.vstack([features,ext_features])
            # labels = np.append(labels, fn.split('/')[1])
            labels = np.append(labels, label)
        print("extract %s features done" % (sub_dir))
    return np.array(features), np.array(labels, dtype = np.int), files_order

def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1
    return one_hot_encode

# Get features and labels
r = os.listdir("./data/")
r.sort()
features, labels, x= parse_audio_files('data', r)
np.save('./feat4.npy', features)
np.save('./label4.npy', labels)
# Out:
# .DS_Store
# extract .DS_Store features done
# song
# data\song\11_harim_sing_01_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_01_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_01_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_01_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_02_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_02_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_02_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_02_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_03_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_03_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_03_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_03_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_04_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_04_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_25000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_30000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_35000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_40000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_harim_sing_05_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_25000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_30000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_35000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_40000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_45000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_50000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_55000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_60000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_65000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_70000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_75000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_80000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_85000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_01_90000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_25000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_30000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_35000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_40000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_45000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_50000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_55000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_60000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_65000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_70000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_02_75000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_25000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_30000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_35000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_40000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_45000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_5000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_50000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_55000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_60000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_henry_sing_03_65000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_10000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_100000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_105000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_110000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_115000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_120000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_125000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_130000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_135000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_140000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_145000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_15000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_150000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_155000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_20000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_25000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_30000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01_35000.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\song\11_lsh_sing_01
wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_71.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_72.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_73.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_74.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_75.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_76.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_77.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_78.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_79.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_80.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_81.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_82.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_83.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_84.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_85.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_86.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_87.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_88.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_89.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_90.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_91.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_92.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_93.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_94.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_95.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_96.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_97.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_98.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\iu_newsroom_99.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_001.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_002.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_003.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_004.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_005.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_006.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_007.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_008.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_009.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_010.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_011.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_012.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_013.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_014.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_015.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_016.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_017.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_018.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_019.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_020.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_021.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_022.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_023.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_024.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_025.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_026.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_027.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\pjh_voice_028.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_10.0-15.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_100.0-105.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_105.0-110.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_110.0-115.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_115.0-120.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_120.0-125.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_125.0-130.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_140.0-145.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_145.0-150.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_15.0-20.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_150.0-155.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_20.0-25.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_25.0-30.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_30.0-35.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_35.0-40.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_40.0-45.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_45.0-50.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_5.0-10.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_50.0-55.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_55.0-60.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_60.0-65.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_65.0-70.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_70.0-75.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_75.0-80.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_80.0-85.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_85.0-90.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_90.0-95.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# data\spch\test_95.0-100.0.wav
# mfcc shape : (40,)
# chroma shape : (12,)
# tonnetz shape : (6,)
# extract spch features done

# %%
# coding= UTF-8

import pickle
import numpy as np
import sklearn
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import pandas as pd

# Load data from numpy file
X =  np.load('feat_1.npy')
y =  np.load('label_1.npy').ravel()
print(y)
# print(y)
# print(type(X), X.shape)
# print(type(y), y.shape)
def convert(x):
    if x == 1:
        return('song')
    if x == 2:
        return('speech')
#     if x == 2:
#         return('clap')

y = np.array(list(map(convert , y)))
print(y)
print('originnal data count :{}'.format(len(X)))

# Split data into training and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print('train data count : {}'.format(len(X_train)))
print('test data count : {}'.format(len(X_test)))


# Simple SVM
print('fitting...')
clf = SVC(C=20.0,probability=True,kernel='rbf',class_weight = {'speech' :1, 'song' : 1}, gamma=0.00001)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = clf.score(X_test, y_test)
print("acc=%0.3f" % acc)
print(pd.crosstab(y_pred, y_test))


filename = 'svm_2.sav'
pickle.dump(clf, open(filename, 'wb'))

# Grid search for best parameters
# Set the parameters by cross-validation
# tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4, 1e-5],
#                      'C': [1, 10 ,20,30,40,50]}]
#                     #  ,
#                     # {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

# scores = ['precision', 'recall']

# for score in scores:
#     print("# Tuning hyper-parameters for %s" % score)
#     print('')

#     clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
#                        scoring='%s_macro' % score)
#     clf.fit(X_train, y_train)

#     print("Best parameters set found on development set:")
#     print('')
#     print(clf.best_params_)
#     print('')
#     print("Grid scores on development set:")
#     print('')
#     means = clf.cv_results_['mean_test_score']
#     stds = clf.cv_results_['std_test_score']
#     for mean, std, params in zip(means, stds, clf.cv_results_['params']):
#         print("%0.3f (+/-%0.03f) for %r"
#               % (mean, std * 2, params))
#     print('')

#     print("Detailed classification report:")
#     print('')
#     print("The model is trained on the full development set.")
#     print("The scores are computed on the full evaluation set.")
#     print('')
#     y_true, y_pred = y_test, clf.predict(X_test)
#     print(classification_report(y_true, y_pred))
#     print('')
# Out:
# [1 1 1 ... 2 2 2]
# ['song' 'song' 'song' ... 'speech' 'speech' 'speech']
# originnal data count :1993
# train data count : 1395
# test data count : 598
# fitting...
# acc=0.903
# col_0   song  speech
# row_0
# song     310      26
# speech    32     230

# %%
x = np.array([1,3,5,7,9,10,11,12,13,2,4])
def func(x):
    if x % 2 == 0:
        return 1
    else:
        return 0
for i in range(len(x)):
    y = np.array(list(map(func, x)))
    print(type(y))
print(x.shape)
print(x)
